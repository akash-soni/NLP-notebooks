# %%
# %cd /content/drive/MyDrive/FDFS_feb_Batch/NLP/Introduction_to_Transformers
# Out:
# /content/drive/MyDrive/FDFS_feb_Batch/NLP/Introduction_to_Transformers

# %%
try:
  from transformers import pipeline
except Exception as e:
  print(e)
  print("installing...")
  # !pip install datasets transformers[sentencepiece] -q
  from transformers import pipeline
# Out:
# No module named 'transformers'
# installing...
#      |████████████████████████████████| 362 kB 29.0 MB/s
#      |████████████████████████████████| 4.4 MB 50.0 MB/s
#      |████████████████████████████████| 1.1 MB 50.3 MB/s
#      |████████████████████████████████| 140 kB 57.8 MB/s
#      |████████████████████████████████| 101 kB 10.9 MB/s
#      |████████████████████████████████| 212 kB 60.0 MB/s
#      |████████████████████████████████| 596 kB 53.8 MB/s
#      |████████████████████████████████| 127 kB 67.7 MB/s
#      |████████████████████████████████| 271 kB 25.8 MB/s
#      |████████████████████████████████| 144 kB 49.6 MB/s
#      |████████████████████████████████| 94 kB 3.7 MB/s
#      |████████████████████████████████| 6.6 MB 49.5 MB/s
#      |████████████████████████████████| 1.2 MB 48.4 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# create a Write token in Hugging_face account (Settings -> Access Tokens -> Create Write Tokens)

from huggingface_hub import notebook_login

notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
# %%bash
# git config --global user.name "c17hawke"
# git config --global user.email "sunny.c17hawke@gmail.com"

# %%
from transformers import AutoModelForSequenceClassification

# %%
# !pwd
# Out:
# /content/drive/MyDrive/FDFS_feb_Batch/NLP/Introduction_to_Transformers

# %%
# loding the model
local_model = AutoModelForSequenceClassification.from_pretrained("./example_model")

# %%
# pushing the model into hugging face repository.
local_model.push_to_hub("example-model-FSDS", use_auth_token="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")
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:43: FutureWarning: Pass token='example-model-FSDS' as keyword args. From version 0.8 passing these as positional arguments will result in an error
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py:644: FutureWarning: `create_repo` now takes `token` as an optional positional argument. Be sure to adapt your code!
#   FutureWarning,
# Cloning https://huggingface.co/akash-soni/example-model-FSDS into local empty directory.
